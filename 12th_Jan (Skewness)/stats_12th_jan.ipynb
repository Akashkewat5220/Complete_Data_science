# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from   scipy.stats import norm
import statistics as stats
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = np.linspace(10,20, 10000)

# %%
x1 = np.random.randn(100000)

# %%
x1
# Out:
# array([-1.56054778,  0.58403574,  0.33820429, ...,  0.76939861,
#         0.58819024, -1.82302395], shape=(100000,))

# %%
np.mean(x1)
# Out:
# np.float64(0.002844276807302093)

# %%
np.std(x1)
# Out:
# np.float64(1.0017447243338136)

# %%
np.median(x1)
# Out:
# np.float64(0.001547926531603642)

# %%
stats.mode(x1)
# Out:
# np.float64(-1.5605477842927462)

# %%
plt.figure(figsize=(10,10))

# %%
norm.pdf(x)
# Out:
# array([7.69459863e-23, 7.61802466e-23, 7.54220519e-23, ...,
#        5.74627403e-88, 5.63248737e-88, 5.52094836e-88], shape=(10000,))

# %%
plt.plot(x1,norm.pdf(x1))
